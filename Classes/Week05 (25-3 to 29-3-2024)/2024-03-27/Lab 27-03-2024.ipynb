# %%
#Python List

#1. Create a list named fruits containing the following fruits: "apple", "banana", "orange", "grape", "kiwi".
list1=["apple", "banana", "orange", "grape", "kiwi"]

#2  Print the third element of the list.
print(list1[2])

#3 Add "pineapple" to the end of the list.
list1.append("pineapple")
print(list1)

#4 Remove "banana" from the list.
del list1[1]
print(list1)

#5 Print the length of the list.
print(len(list1))

#6 Check if "grape" is in the list
if "grape" in list1:
    print("Yes")
else:
    print("NO")
# Out:
# orange
# ['apple', 'banana', 'orange', 'grape', 'kiwi', 'pineapple']
# ['apple', 'orange', 'grape', 'kiwi', 'pineapple']
# 5
# Yes

# %%
#Python Tuple

#1. Create a tuple named colors containing the following colors: "red", "green", "blue", "yellow", "orange"
tuple1=("red", "green", "blue", "yellow", "orange")
print(type(tuple1),tuple1)

#2. Print the second element of the tuple.
print(tuple1[1])

#3 Print the index of "blue" in the tuple.
print(tuple1.index("blue"))

#4 Check if "black" is in the tuple.
if "black" in list1:
    print("Yes, Black color in tuple")
else:
    print("Black color is NOT in tuple")
# Out:
# <class 'tuple'> ('red', 'green', 'blue', 'yellow', 'orange')
# green
# 2
# Black color is NOT in tuple

# %%
#Dictionary

#1. Create a dictionary named ages with the following key-value pairs: "Alice": 30, "Bob": 25, "Charlie": 35, "David": 40.
dict = {"Alice": 30, "Bob": 25, "Charlie": 35, "David": 40}

#2. Print the age of "Charlie".
print(dict.get("Charlie"), dict["Charlie"])

#3. Add "Eve" with age 28 to the dictionary.
dict["Eve"]=28
print(dict)

#4.  Remove "David" from the dictionary.
del dict["David"]
print(dict)

#5. Print the keys of the dictionary
print(dict.keys())
# Out:
# 35 35
# {'Alice': 30, 'Bob': 25, 'Charlie': 35, 'David': 40, 'Eve': 28}
# {'Alice': 30, 'Bob': 25, 'Charlie': 35, 'Eve': 28}
# dict_keys(['Alice', 'Bob', 'Charlie', 'Eve'])

# %%
#Pandas DataFrame

#1. Create a DataFrame named students with columns "Name" and "Age" containing the following data
import pandas as pd
data = {
        "Name":["Sohail","Sameer","Sandesh","Nouman"],
        "Age":[25,22,28,30]
        }
df=pd.DataFrame(data)
print(df)

#2. Print the first 2 rows of the DataFrame.
print(df.head(2))

#3. Print the mean age of the students.
print(f"Mean is {df['Age'].mean()}")
# Out:
#       Name  Age
# 0   Sohail   25
# 1   Sameer   22
# 2  Sandesh   28
# 3   Nouman   30
#      Name  Age
# 0  Sohail   25
# 1  Sameer   22
# Mean is 26.25

# %%
# Sets

#1. Create two sets named set1 and set2 containing the following elements: set1={1, 2, 3, 4, 5} and set2={4, 5, 6, 7, 8}.
set1={1, 2, 3, 4, 5}
set2={4, 5, 6, 7, 8}
print(f"Set1: {set1} | Set2: {set2}")

#2. Print the union of set1 and set2.
print(f"Union: {set1.union(set2)}")

#3. Print the intersection of set1 and set2.
print(f"Intersection: {set1.intersection(set2)}")

#4.Add element 9 to set1.
set1.add(9)
print(f"Add: {set1}")

#5. Remove element 4 from set2.
set2.remove(4)
print(f"Remove: {set2}")
# Out:
# Set1: {1, 2, 3, 4, 5} | Set2: {4, 5, 6, 7, 8}
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}
# Add: {1, 2, 3, 4, 5, 9}
# Remove: {5, 6, 7, 8}

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('dataset.csv')
print(df)

info_per1=df.groupby('sex').mean()
info_per2=df.groupby('sex').mean().reset_index()
print(info_per1)
print(df.mean())
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1    137    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]
#            age        cp    trestbps        chol      fbs   restecg  \
# sex
# 0    55.677083  1.041667  133.083333  261.302083  0.12500  0.572917
# 1    56.657005  0.932367  130.946860  239.289855  0.15942  0.507246
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# sex
# 0    151.125000  0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    148.961353  0.371981  1.115459  1.386473  0.811594  2.400966  0.449275
# age          56.346535
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
#import matplotlib.pyplot as plt
heart_data=pd.read_csv('dataset.csv')
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1    137    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# 6. Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='sex', y='age', data=heart_data)
plt.title('Violin Plot: Age by Gender', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.grid(True)
plt.show()
