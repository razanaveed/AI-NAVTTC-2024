# %%
# task 1
number = int(input("enter number: "))
result = number + 3 # 5
result *= 2 #   result = result *2 # 10
result -= 4 # result = result -4 #6
result += 3 # result = result +3 # 9
print("result is: ",result)
# Out:
# enter number: 2
# result is:  9

# %%
# task 2
Celsius = float(input("Enter temp in Celsius: "))
Fahrenheit = (Celsius * 1.8) + 32
print("Temp in Fahrenheit is: ",Fahrenheit)
# Out:
# enter temp in Celsius:37.5
# Temp in Fahrenheit is:  99.5

# %%
# task 3
import math as mp
radius = float(input("Enter Radius of the circle: "))
Area = mp.pi*radius*radius
print("Area of the Circle is: ",Area)
# Out:
# Enter Radius of the circle: 15
# Area of the Circle is:  706.8583470577034

# %%
# task 4
colour = input("Enter your favourite colour: ")
print(colour*10)
print(colour+" "*(len(colour)*8)+colour)
print(colour*10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b8fdb8095587> in <cell line: 2>()
#       1 # task 4
# ----> 2 colour = input("Enter your favourite colour: ")
#       3 print(colour*10)
#       4 print(colour+" "*(len(colour)*8)+colour)
#       5 print(colour*10)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
# task 5
name = input("Enter Person Name: ")
print("Given name is:",name)
print("Tab Character: START=> \t", name , "\t" , "<=END TAB")
print("New line Character: START=> \n", name , "\n" , "<=END")
print("Left Strip:", name.lstrip())
print("Right Strip:", name.rstrip())
print("Strip Both:", name.strip())
# Out:
# Enter Person Name:      Raza    Naveed
# Given name is:      Raza    Naveed
# Tab Character: START=> 	      Raza    Naveed     	 <=END TAB
# New line Character: START=>
#       Raza    Naveed
#  <=END
# Left Strip: Raza    Naveed
# Right Strip:      Raza    Naveed
# Strip Both: Raza    Naveed

# %%
# task 6 MODULUS REMAINDER
Dividend = int(input("Enter Dividend : "))
Divisor  = int(input("Enter Divisor  : "))
Quotient = int(Dividend / Divisor)
Remainder = Dividend % Divisor
print("Using Modulus  => Quotient=",Quotient," | Remainder=",Remainder)

# method 2
quot,remain=divmod(Dividend, Divisor)
print("Using Function => Quotient=",quot," | Remainder=",remain)
# Out:
# Enter Dividend : 11
# Enter Divisor  : 3
# Using Modulus  => Quotient= 3  | Remainder= 2
# Using Function => Quotient= 3  | Remainder= 2

# %%
# task 7 LENGTH
data="This is my first program!"
print("Length is: ", len(data))
# Out:
# Length is:  25

# %%
# task 8   SWAP VALUE
a=10
b=5
temp=a
a=b
b=temp
print(a,b)
# Out:
# 5 10
